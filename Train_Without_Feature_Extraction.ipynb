# %% [markdown]
# <a href="https://colab.research.google.com/github/assaabriiii/AI/blob/main/Train_Without_Feature_Extraction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from sklearn.neural_network import MLPClassifier
import time
import numpy as np
from sklearn.datasets import fetch_openml
from sklearn.model_selection import train_test_split
from sklearn.neural_network import MLPClassifier

X_raw, y_raw = fetch_openml('mnist_784', version=1, return_X_y=True, as_frame=False)
X_raw = X_raw / 255.0
y_raw = y_raw.astype(int)

X_train_raw, X_test_raw, y_train_raw, y_test_raw = train_test_split(
    X_raw, y_raw, test_size=0.2, random_state=42, stratify=y_raw)

print("Training 784-pixel MLP (no features)...")
start = time.time()

mlp_raw = MLPClassifier(
    hidden_layer_sizes=(10,),
    activation='relu',
    learning_rate='constant',
    learning_rate_init=0.01,
    batch_size=64,
    max_iter=200,
    random_state=42
)

mlp_raw.fit(X_train_raw, y_train_raw)
time_784 = time.time() - start

acc_784 = mlp_raw.score(X_test_raw, y_test_raw)

print("\n" + "="*50)
print("FINAL COMPARISON")
print("="*50)
# print(f"With 4×4 features (49 inputs)  → Accuracy: {final_mlp.score(X_test,y_test):.4f} | Time: ~12 sec")
print(f"Without features (784 inputs) → Accuracy: {acc_784:.4f} | Time: {time_784:.1f} sec")
print(f"Speed-up: {time_784/12:.1f}× slower")
# print(f"Accuracy drop: {(final_mlp.score(X_test,y_test) - acc_784):.4f}")
print("="*50)
# Out:
# Training 784-pixel MLP (no features)...
#
# ...
# FINAL COMPARISON
# ...
# Without features (784 inputs) → Accuracy: 0.9311 | Time: 56.8 sec
# Speed-up: 4.7× slower
# ...
